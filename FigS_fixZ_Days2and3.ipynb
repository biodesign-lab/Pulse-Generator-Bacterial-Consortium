# %% [markdown]
# ### Figure S... for days 2 and 3 of fixZ
#
# Here we create supplementary Figure S ... .

# %%
import os
print(os.getcwd())
import numpy as np
import seaborn as sns
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
import matplotlib.pyplot as plt
import scipy.io as sio
# Out:
# C:\Users\mathuser\Google Drive\Python\Jupyter Notebook\PNAS figures

# %%
# Load the data from matlab .mat file
fixZData = sio.loadmat('fixZ_varyXtoY.mat')
numDataPoints=len(fixZData['all_flu'][:,0,0,0,0])
time_vec=np.array(range(0,numDataPoints*10,10))
ts=270 #start of the saturation pahse of the cell growth 


sns.set()
sns.set(font_scale=1.2)
sns.set_style('ticks')
red_colors = sns.color_palette("Reds_d",9)
blue_colors = sns.color_palette("Blues_d",9)
orange_colors = sns.color_palette("YlOrBr_d",9)
Fig2 = plt.figure(figsize=(8,10))


#Store the data for all 9 conditions of day 2 of fixZ (mean of 6 replicates)
day=1 #day 2 of the fix Z experiment
X_9cond=np.zeros([numDataPoints, 9])
Y_9cond=np.zeros([numDataPoints, 9])
Z_9cond=np.zeros([numDataPoints, 9])
for c in range(9):
    X_reps=np.zeros([numDataPoints, 6])
    Y_reps=np.zeros([numDataPoints, 6])
    Z_reps=np.zeros([numDataPoints, 6])
    for repl in range(6):
        X=fixZData['all_flu'][:,repl,c,0,day]
        Y=fixZData['all_flu'][:,repl,c,1,day]
        Z=fixZData['all_flu'][:,repl,c,2,day]
        X=X-np.mean(X[0:11])
        Y=Y-np.mean(Y[0:11])
        Z=Z-np.mean(Z[0:11])
        X_reps[:, repl]=X
        Y_reps[:, repl]=Y
        Z_reps[:, repl]=Z
    X_9cond[:,c] = np.mean(X_reps, axis=1)
    Y_9cond[:,c] = np.mean(Y_reps, axis=1)
    Z_9cond[:,c] = np.mean(Z_reps, axis=1)


#Plot 9 conditions of fixZ experiment for strain X 
plt.subplot(3,2,1)
for c in range(9):
    plt.plot(time_vec,X_9cond[:,8-c], color=red_colors[c], lw=1, label='X:Y= {}:{}'.format(c+1,9-c))   
plt.axvline(ts, linestyle='--', color='k', lw=1, alpha=0.3)
plt.legend(fontsize=9, frameon=False)
plt.xticks((0,240,480),(0,240,480))
plt.yticks((0,3000),(0,3000))
plt.title('Day 2 ($r_Z=0.33$)', fontsize=20)
sns.despine()

#Plot 9 conditions of fixZ experiment for strain Y 
plt.subplot(3,2,3)
for c in range(9):
    plt.plot(time_vec,Y_9cond[:,8-c], color=blue_colors[c], lw=1, label='X:Y= {}:{}'.format(c+1,9-c))    
plt.axvline(ts, linestyle='--', color='k', lw=1, alpha=0.3)
plt.legend(fontsize=9, frameon=False)
plt.xticks((0,240,480),(0,240,480))
plt.yticks((0,20000),(0,20000))
sns.despine()

#Plot 9 conditions of fixZ experiment for strain Z 
plt.subplot(3,2,5)
for c in range(9):
    plt.plot(time_vec,Z_9cond[:,8-c], color=orange_colors[c], lw=1, label='X:Y= {}:{}'.format(c+1,9-c))  
plt.axvline(ts, linestyle='--', color='k', lw=1, alpha=0.3)
plt.legend(fontsize=9, frameon=False)
plt.xticks((0,240,480),(0,240,480))
plt.yticks((0,4000),(0,4000))
plt.ylim([-250, 5000])
sns.despine()



#Store the data for all 9 conditions of day 3 of fixZ (mean of 6 replicates)
day=2 #day 3 of the fix Z experiment
X_9cond=np.zeros([numDataPoints, 9])
Y_9cond=np.zeros([numDataPoints, 9])
Z_9cond=np.zeros([numDataPoints, 9])
for c in range(8):
    X_reps=np.zeros([numDataPoints, 6])
    Y_reps=np.zeros([numDataPoints, 6])
    Z_reps=np.zeros([numDataPoints, 6])
    for repl in range(6):
        X=fixZData['all_flu'][:,repl,c,0,day]
        Y=fixZData['all_flu'][:,repl,c,1,day]
        Z=fixZData['all_flu'][:,repl,c,2,day]
        X=X-np.mean(X[0:11])
        Y=Y-np.mean(Y[0:11])
        Z=Z-np.mean(Z[0:11])
        X_reps[:, repl]=X
        Y_reps[:, repl]=Y
        Z_reps[:, repl]=Z
    X_9cond[:,c] = np.mean(X_reps, axis=1)
    Y_9cond[:,c] = np.mean(Y_reps, axis=1)
    Z_9cond[:,c] = np.mean(Z_reps, axis=1)

c=8
X_reps=np.zeros([numDataPoints, 5])
Y_reps=np.zeros([numDataPoints, 5])
Z_reps=np.zeros([numDataPoints, 5])
for repl in range(3):
    X=fixZData['all_flu'][:,repl,c,0,day]
    Y=fixZData['all_flu'][:,repl,c,1,day]
    Z=fixZData['all_flu'][:,repl,c,2,day]
    X=X-np.mean(X[0:11])
    Y=Y-np.mean(Y[0:11])
    Z=Z-np.mean(Z[0:11])
    X_reps[:, repl]=X
    Y_reps[:, repl]=Y
    Z_reps[:, repl]=Z
for repl in range(4,6):
    X=fixZData['all_flu'][:,repl,c,0,day]
    Y=fixZData['all_flu'][:,repl,c,1,day]
    Z=fixZData['all_flu'][:,repl,c,2,day]
    X=X-np.mean(X[0:11])
    Y=Y-np.mean(Y[0:11])
    Z=Z-np.mean(Z[0:11])
    X_reps[:, repl-1]=X
    Y_reps[:, repl-1]=Y
    Z_reps[:, repl-1]=Z    
X_9cond[:,c] = np.mean(X_reps, axis=1)
Y_9cond[:,c] = np.mean(Y_reps, axis=1)
Z_9cond[:,c] = np.mean(Z_reps, axis=1)

#Plot 9 conditions of fixZ experiment for strain X 
plt.subplot(3,2,2)
for c in range(9):
    plt.plot(time_vec,X_9cond[:,8-c], color=red_colors[c], lw=1, label='X:Y= {}:{}'.format(c+1,9-c))   
plt.axvline(ts, linestyle='--', color='k', lw=1, alpha=0.3)
plt.legend(fontsize=9, frameon=False)
plt.xticks((0,240,480),(0,240,480))
plt.yticks((0,3000),(0,3000))
plt.title('Day 3 ($r_Z=0.33$)', fontsize=20)
sns.despine()

#Plot 9 conditions of fixZ experiment for strain Y 
plt.subplot(3,2,4)
for c in range(9):
    plt.plot(time_vec,Y_9cond[:,8-c], color=blue_colors[c], lw=1, label='X:Y= {}:{}'.format(c+1,9-c))    
plt.axvline(ts, linestyle='--', color='k', lw=1, alpha=0.3)
plt.legend(fontsize=9, frameon=False)
plt.xticks((0,240,480),(0,240,480))
plt.yticks((0,20000),(0,20000))
sns.despine()

#Plot 9 conditions of fixZ experiment for strain Z 
plt.subplot(3,2,6)
for c in range(9):
    plt.plot(time_vec,Z_9cond[:,8-c], color=orange_colors[c], lw=1, label='X:Y= {}:{}'.format(c+1,9-c))  
plt.axvline(ts, linestyle='--', color='k', lw=1, alpha=0.3)
plt.legend(fontsize=9, frameon=False)
plt.xticks((0,240,480),(0,240,480))
plt.yticks((0,4000),(0,4000))
plt.ylim([-250, 5000])
sns.despine()



Fig2.subplots_adjust(wspace=0.4)
Fig2.savefig("FigS_fixZ_days2and3.pdf", bbox_inches='tight', transparent=True)
